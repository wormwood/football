# %%
from FixturesOdds import FixturesOdds
# %load_ext autoreload 
# %autoreload 2
import requests
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from FixturesOdds import FixturesOdds
from datetime import datetime

# %%
fix_pred=FixturesOdds()

# %%
fix_pred.get_odds('skybet',1)
# Out:
#                    HomeTeam     fixdate  HomeOdds  DrawOdds  AwayOdds
# 0           AFC Bournemouth  2018-11-03      3.60      3.60      2.00
# 1           West Ham United  2018-11-03      1.75      3.50      4.80
# 2          Newcastle United  2018-11-03      2.63      3.10      2.80
# 3                   Everton  2018-11-03      1.62      3.75      5.25
# 4              Cardiff City  2018-11-03      3.50      3.25      2.15
# 5                   Arsenal  2018-11-03      3.30      3.80      2.00
# 6   Wolverhampton Wanderers  2018-11-03      3.30      3.40      2.15
# 7           Manchester City  2018-11-04      1.13      8.50     19.00
# 8                   Chelsea  2018-11-04      1.29      5.50     10.00
# 9         Huddersfield Town  2018-11-05      2.20      3.40      3.10
# 10             Cardiff City  2018-11-10      2.50      3.10      3.00
# 11           Leicester City  2018-11-10      1.62      3.75      5.75
# 12        Huddersfield Town  2018-11-10      3.30      3.10      2.30
# 13              Southampton  2018-11-10      2.25      3.25      3.25
# 14         Newcastle United  2018-11-10      2.63      3.30      2.63
# 15           Crystal Palace  2018-11-10      4.00      3.80      1.83
# 16                Liverpool  2018-11-11      1.11      9.00     21.00
# 17                  Chelsea  2018-11-11      1.40      4.80      7.50
# 18                  Arsenal  2018-11-11      1.60      4.00      5.25
# 19          Manchester City  2018-11-11      1.40      4.80      7.50

# %%
def swap (row):
    if row[0]!= row[2]:
        return[row[0], row[1],row[2],row[3],row['AwayOdds'], row['DrawOdds'], row['HomeOdds']]
    else:
        return[row[0], row[1],row[2],row[3],row['HomeOdds'], row['DrawOdds'], row['AwayOdds']]

# %%
def format_commence_time(commence_time):
    return datetime.utcfromtimestamp(int(commence_time)).strftime('%Y-%m-%d')

# %%
leaugeid=1
bookie_key='skybet'

apiKey='fc3fa79ee130aa6427d2d86743b794fc'
apiKey = 'edddec034215860d93d49887ede78024'
sports = {1 : 'soccer_epl', 2: 'soccer_efl_champ'}
sport = sports[leaugeid]
url = "https://api.the-odds-api.com/v3/odds/?sport=%s&region=uk&apiKey=%s" % (sport,apiKey)

#url="https://api.the-odds-api.com/v3/odds/?sport=soccer_epl&region=uk&apiKey=fc3fa79ee130aa6427d2d86743b794fc"
r = requests.get(url=url)
json=r.json()
games = json['data']

home_teams = [game['home_team'] for game in games]
sites = [game['sites'] for game in games]
odds=[s['odds']['h2h'] for site in sites for s in site if s['site_key']==bookie_key]
dates=[format_commence_time(game['commence_time']) for game in games]
first_team = [game['teams'][0] for game in games]

# %%
x =  list(zip(home_teams,odds,first_team,dates))

df1=pd.DataFrame(x)

df1[['HomeOdds', 'AwayOdds', 'DrawOdds']]=pd.DataFrame(df1[1].values.tolist(), index=df1.index)
df1=df1[[0,1,2,3,'HomeOdds', 'DrawOdds', 'AwayOdds']].apply(swap,1)
df1.replace({'Bournemouth' : 'AFC Bournemouth'}, inplace=True)
df1.replace({'Brighton and Hove Albion' : 'Brighton & Hove Albion'}, inplace=True)
df1.rename(columns={0:'HomeTeam',3:'fixdate'}, inplace=True)
df1
# Out:
#                    HomeTeam                   1                       2  \
# 0           AFC Bournemouth       [3.5, 2, 3.6]         AFC Bournemouth
# 1           West Ham United   [4.75, 1.75, 3.6]                 Burnley
# 2          Newcastle United    [2.7, 2.75, 3.1]        Newcastle United
# 3                   Everton   [5.5, 1.62, 3.75]  Brighton & Hove Albion
# 4              Cardiff City    [3.4, 2.2, 3.25]            Cardiff City
# 5                   Arsenal  [3.25, 2.05, 3.75]                 Arsenal
# 6   Wolverhampton Wanderers    [2.2, 3.25, 3.4]       Tottenham Hotspur
# 7           Manchester City     [1.13, 19, 8.5]         Manchester City
# 8                   Chelsea       [1.25, 11, 6]                 Chelsea
# 9         Huddersfield Town    [3.2, 2.25, 3.3]                  Fulham
# 10             Cardiff City       [3, 2.5, 3.1]  Brighton & Hove Albion
# 11           Leicester City  [5.75, 1.62, 3.75]                 Burnley
# 12        Huddersfield Town     [3.3, 2.3, 3.1]       Huddersfield Town
# 13              Southampton     [2.3, 3.2, 3.2]             Southampton
# 14         Newcastle United     [2.8, 2.5, 3.3]         AFC Bournemouth
# 15           Crystal Palace      [4, 1.83, 3.8]          Crystal Palace
# 16                Liverpool       [21, 1.11, 9]                  Fulham
# 17                  Chelsea     [1.4, 7.5, 4.8]                 Chelsea
# 18                  Arsenal      [1.6, 5.25, 4]                 Arsenal
# 19          Manchester City     [1.4, 7.5, 4.8]         Manchester City
#
#        fixdate  HomeOdds  DrawOdds  AwayOdds
# 0   2018-11-03      3.50      3.60      2.00
# 1   2018-11-03      1.75      3.60      4.75
# 2   2018-11-03      2.70      3.10      2.75
# 3   2018-11-03      1.62      3.75      5.50
# 4   2018-11-03      3.40      3.25      2.20
# 5   2018-11-03      3.25      3.75      2.05
# 6   2018-11-03      3.25      3.40      2.20
# 7   2018-11-04      1.13      8.50     19.00
# 8   2018-11-04      1.25      6.00     11.00
# 9   2018-11-05      2.25      3.30      3.20
# 10  2018-11-10      2.50      3.10      3.00
# 11  2018-11-10      1.62      3.75      5.75
# 12  2018-11-10      3.30      3.10      2.30
# 13  2018-11-10      2.30      3.20      3.20
# 14  2018-11-10      2.50      3.30      2.80
# 15  2018-11-10      4.00      3.80      1.83
# 16  2018-11-11      1.11      9.00     21.00
# 17  2018-11-11      1.40      4.80      7.50
# 18  2018-11-11      1.60      4.00      5.25
# 19  2018-11-11      1.40      4.80      7.50

# %%
pd.DataFrame(x)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#     340             if method is not None:
# --> 341                 return method()
#     342             return None
#     343         else:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in _repr_html_(self)
#     603
#     604         # used by repr_html under IPython notebook or scripts ignore terminal
# --> 605         # dims
#     606         if ignore_width or not com.in_interactive_session():
#     607             return True
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in _info_repr(self)
#     560         See Also
#     561         --------
# --> 562         ndarray.shape
#     563
#     564         Examples
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/config.py in __call__(self, *args, **kwds)
#     225
#     226     def __call__(self, *args, **kwds):
# --> 227         return self.__func__(*args, **kwds)
#     228
#     229     @property
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/config.py in _get_option(pat, silent)
#      95
#      96 def _get_option(pat, silent=False):
# ---> 97     key = _get_single_key(pat, silent)
#      98
#      99     # walk the nested dict
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/config.py in _get_single_key(pat, silent)
#      81         if not silent:
#      82             _warn_if_deprecated(pat)
# ---> 83         raise OptionError('No such keys(s): {pat!r}'.format(pat=pat))
#      84     if len(keys) > 1:
#      85         raise OptionError('Pattern matched multiple keys')
#
# OptionError: "No such keys(s): 'display.large_repr'"
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     695                 type_pprinters=self.type_printers,
#     696                 deferred_pprinters=self.deferred_printers)
# --> 697             printer.pretty(obj)
#     698             printer.flush()
#     699             return stream.getvalue()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/lib/pretty.py in _default_pprint(obj, p, cycle)
#     501     if _safe_getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     502         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 503         _repr_pprint(obj, p, cycle)
#     504         return
#     505     p.begin_group(1, '<')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     683     """A pprint that just redirects to the normal repr function."""
#     684     # Find newlines and replace them with p.break_()
# --> 685     output = repr(obj)
#     686     for idx,output_line in enumerate(output.splitlines()):
#     687         if idx:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/base.py in __repr__(self)
#      70         """
#      71         from pandas.core.config import get_option
# ---> 72
#      73         encoding = get_option("display.encoding")
#      74         return self.__unicode__().encode(encoding, 'replace')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/base.py in __str__(self)
#      49     def __unicode__(self):
#      50         raise AbstractMethodError(self)
# ---> 51
#      52     def __str__(self):
#      53         """
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in __unicode__(self)
#     572         >>> df.shape
#     573         (2, 3)
# --> 574         """
#     575         return len(self.index), len(self.columns)
#     576
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in _info_repr(self)
#     560         See Also
#     561         --------
# --> 562         ndarray.shape
#     563
#     564         Examples
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/config.py in __call__(self, *args, **kwds)
#     225
#     226     def __call__(self, *args, **kwds):
# --> 227         return self.__func__(*args, **kwds)
#     228
#     229     @property
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/config.py in _get_option(pat, silent)
#      95
#      96 def _get_option(pat, silent=False):
# ---> 97     key = _get_single_key(pat, silent)
#      98
#      99     # walk the nested dict
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/config.py in _get_single_key(pat, silent)
#      81         if not silent:
#      82             _warn_if_deprecated(pat)
# ---> 83         raise OptionError('No such keys(s): {pat!r}'.format(pat=pat))
#      84     if len(keys) > 1:
#      85         raise OptionError('Pattern matched multiple keys')
#
# OptionError: "No such keys(s): 'display.large_repr'"
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#     340             if method is not None:
# --> 341                 return method()
#     342             return None
#     343         else:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/generic.py in _repr_latex_(self)
#    1057             d[axis] = mapper
#    1058             return self.rename(**d)
# -> 1059
#    1060     def _set_axis_name(self, name, axis=0, inplace=False):
#    1061         """
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/config.py in __call__(self, *args, **kwds)
#     225
#     226     def __call__(self, *args, **kwds):
# --> 227         return self.__func__(*args, **kwds)
#     228
#     229     @property
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/config.py in _get_option(pat, silent)
#      95
#      96 def _get_option(pat, silent=False):
# ---> 97     key = _get_single_key(pat, silent)
#      98
#      99     # walk the nested dict
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/config.py in _get_single_key(pat, silent)
#      81         if not silent:
#      82             _warn_if_deprecated(pat)
# ---> 83         raise OptionError('No such keys(s): {pat!r}'.format(pat=pat))
#      84     if len(keys) > 1:
#      85         raise OptionError('Pattern matched multiple keys')
#
# OptionError: "No such keys(s): 'display.latex.repr'"

# %%
df1[['HomeOdds', 'AwayOdds', 'DrawOdds']]=pd.DataFrame(df1[1].values.tolist(), index=df1.index)
df1=df1[[0,1,2,'HomeOdds', 'DrawOdds', 'AwayOdds']].apply(swap,1)
df1.replace({'Bournemouth' : 'AFC Bournemouth'}, inplace=True)
df1.replace({'Brighton and Hove Albion' : 'Brighton & Hove Albion'}, inplace=True)
df1.rename(columns={0:'HomeTeam'}, inplace=True)
#        return df1[['HomeTeam','HomeOdds', 'DrawOdds', 'AwayOdds']]

# %%
    def xx(bookie_key, leaugeid):
        
        apiKey='fc3fa79ee130aa6427d2d86743b794fc'
        apiKey = 'edddec034215860d93d49887ede78024'
        sports = {1 : 'soccer_epl', 2: 'soccer_efl_champ'}
        sport = sports[leaugeid]
        url = "https://api.the-odds-api.com/v3/odds/?sport=%s&region=uk&apiKey=%s" % (sport,apiKey)

        #url="https://api.the-odds-api.com/v3/odds/?sport=soccer_epl&region=uk&apiKey=fc3fa79ee130aa6427d2d86743b794fc"
        r = requests.get(url=url)
        json=r.json()
        games = json['data']

        home_teams = [game['home_team'] for game in games]
        sites = [game['sites'] for game in games]
        odds=[s['odds']['h2h'] for site in sites for s in site if s['site_key']==bookie_key]
        
        first_team = [game['teams'][0] for game in games]
        x =  list(zip(home_teams,odds,first_team))
        
        df1=pd.DataFrame(x)
        
        df1[['HomeOdds', 'AwayOdds', 'DrawOdds']]=pd.DataFrame(df1[1].values.tolist(), index=df1.index)
        df1=df1[[0,1,2,'HomeOdds', 'DrawOdds', 'AwayOdds']].apply(swap,1)
        df1.replace({'Bournemouth' : 'AFC Bournemouth'}, inplace=True)
        df1.rename(columns={0:'HomeTeam'}, inplace=True)
        return df1[['HomeTeam','HomeOdds', 'DrawOdds', 'AwayOdds']]
        
#        df1.replace({'Bournemouth' : 'AFC Bournemouth'}, inplace=True)
#        df1.rename(columns={0:'HomeTeam'}, inplace=True)
        
#        return df1 #[['HomeTeam','HomeOdds', 'DrawOdds', 'AwayOdds']]

# %%
d=xx('ladbrokes',2)
d
# Out:
#                HomeTeam  HomeOdds  DrawOdds  AwayOdds
# 0   Sheffield Wednesday      3.40      3.20      2.20
# 1      Blackburn Rovers      3.25      3.30      2.20
# 2        Wigan Athletic      3.10      3.50      2.20
# 3            Stoke City      2.00      3.20      4.00
# 4             Brentford      1.75      3.70      4.50
# 5               Reading      2.75      3.10      2.60
# 6             Hull City      2.65      3.30      2.60
# 7      Rotherham United      2.20      3.20      3.40
# 8           Aston Villa      1.87      3.50      4.20
# 9          Ipswich Town      2.65      3.10      2.75
# 10    Nottingham Forest      2.30      3.25      3.10
# 11         Derby County      2.55      3.30      2.70
# 12         Norwich City      2.38      3.20      3.00
# 13             Millwall      2.20      3.20      3.40
# 14         Swansea City      2.20      3.20      3.30
# 15        Middlesbrough      1.00       NaN      1.00
# 16  Queens Park Rangers      1.91      3.40      4.20
# 17     Sheffield United      2.30      3.30      3.00
# 18      Birmingham City      1.80      3.50      4.60
# 19              Preston      1.44      4.25      7.50
# 20         Bristol City      1.00       NaN      1.00
# 21         Leeds United      1.95      3.40      3.80

# %%
# Out:
#                     HomeTeam  HomeOdds DrawOdds  AwayOdds
# 0                    Chelsea      1.70      3.8      5.00
# 1               Cardiff City      2.40      3.3      2.80
# 2           Newcastle United      2.15        b      3.70
# 3            AFC Bournemouth      2.00      3.5      3.60
# 4            Manchester City      1.07        b     34.00
# 5    Wolverhampton Wanderers      1.73        b      5.00
# 6            West Ham United      4.00        b      1.80
# 7          Huddersfield Town     12.00        5      1.30
# 8                    Everton      1.83        b      4.33
# 9                    Arsenal      1.53     4.33      5.75
# 10               Southampton      2.15        b      3.50
# 11                 Liverpool      1.09        b     34.00
# 12                    Fulham      2.65        b      2.45
# 13  Brighton and Hove Albion      3.10      3.1      2.40
# 14                   Watford      1.75        b      4.80
# 15            Leicester City      1.83      3.7      4.00
# 16            Crystal Palace      1.67        b      5.20
# 17                   Burnley      1.83     3.75      4.00

# %%
d.replace({'Bournemouth' : 'AFC Bournemouth'}, inplace=True)
d.rename(columns={0:'HomeTeam'}, inplace=True)
d[['HomeTeam','HomeOdds', 'DrawOdds', 'AwayOdds']]
# Out:
#                     HomeTeam  HomeOdds  DrawOdds  AwayOdds
# 0                    Chelsea      1.70      3.80      5.00
# 1               Cardiff City      2.40      3.30      2.80
# 2           Newcastle United      3.60      3.10      2.15
# 3            AFC Bournemouth      2.00      3.50      3.60
# 4            Manchester City     34.00     13.00      1.07
# 5    Wolverhampton Wanderers      5.00      3.50      1.73
# 6            West Ham United      1.80      3.50      4.00
# 7          Huddersfield Town     12.00      5.00      1.30
# 8                    Everton      4.33      3.50      1.83
# 9                    Arsenal      1.53      4.33      5.75
# 10               Southampton      3.50      3.20      2.15
# 11                 Liverpool     34.00     10.00      1.09
# 12                    Fulham      2.45      3.60      2.65
# 13  Brighton and Hove Albion      3.10      3.10      2.40
# 14                   Watford      4.80      3.40      1.75
# 15            Leicester City      1.83      3.70      4.00
# 16            Crystal Palace      5.20      3.75      1.67
# 17                   Burnley      1.83      3.75      4.00

# %%
d[[0,1,2,'HomeOdds', 'DrawOdds', 'AwayOdds']]
# Out:
#                            0                   1                         2  \
# 0                    Chelsea       [1.7, 5, 3.8]                   Chelsea
# 1               Cardiff City     [2.4, 2.8, 3.3]              Cardiff City
# 2           Newcastle United    [3.6, 2.15, 3.1]  Brighton and Hove Albion
# 3                Bournemouth       [2, 3.6, 3.5]               Bournemouth
# 4            Manchester City      [34, 1.07, 13]                   Burnley
# 5    Wolverhampton Wanderers      [5, 1.73, 3.5]                   Watford
# 6            West Ham United       [1.8, 4, 3.5]         Tottenham Hotspur
# 7          Huddersfield Town        [12, 1.3, 5]         Huddersfield Town
# 8                    Everton   [4.33, 1.83, 3.5]            Crystal Palace
# 9                    Arsenal  [1.53, 5.75, 4.33]                   Arsenal
# 10               Southampton    [3.5, 2.15, 3.2]          Newcastle United
# 11                 Liverpool      [34, 1.09, 10]              Cardiff City
# 12                    Fulham   [2.45, 2.65, 3.6]               Bournemouth
# 13  Brighton and Hove Albion     [3.1, 2.4, 3.1]  Brighton and Hove Albion
# 14                   Watford    [4.8, 1.75, 3.4]         Huddersfield Town
# 15            Leicester City      [1.83, 4, 3.7]            Leicester City
# 16            Crystal Palace   [5.2, 1.67, 3.75]                   Arsenal
# 17                   Burnley     [1.83, 4, 3.75]                   Burnley
#
#     HomeOdds  DrawOdds  AwayOdds
# 0       1.70      3.80      5.00
# 1       2.40      3.30      2.80
# 2       2.15      3.10      3.60
# 3       2.00      3.50      3.60
# 4       1.07     13.00     34.00
# 5       1.73      3.50      5.00
# 6       4.00      3.50      1.80
# 7      12.00      5.00      1.30
# 8       1.83      3.50      4.33
# 9       1.53      4.33      5.75
# 10      2.15      3.20      3.50
# 11      1.09     10.00     34.00
# 12      2.65      3.60      2.45
# 13      3.10      3.10      2.40
# 14      1.75      3.40      4.80
# 15      1.83      3.70      4.00
# 16      1.67      3.75      5.20
# 17      1.83      3.75      4.00

# %%
saved_away=d['AwayOdds']
swapindex=d[0]!=d[2] # if the home team is wrong
d.loc[swapindex, 'AwayOdds']=d['HomeOdds'] 
d.loc[swapindex, 'HomeOdds']=saved_away
d
# Out:
#                            0                   1                         2  \
# 0                    Chelsea       [1.7, 5, 3.8]                   Chelsea
# 1               Cardiff City     [2.4, 2.8, 3.3]              Cardiff City
# 2           Newcastle United    [3.6, 2.15, 3.1]  Brighton and Hove Albion
# 3                Bournemouth       [2, 3.6, 3.5]               Bournemouth
# 4            Manchester City      [34, 1.07, 13]                   Burnley
# 5    Wolverhampton Wanderers      [5, 1.73, 3.5]                   Watford
# 6            West Ham United       [1.8, 4, 3.5]         Tottenham Hotspur
# 7          Huddersfield Town        [12, 1.3, 5]         Huddersfield Town
# 8                    Everton   [4.33, 1.83, 3.5]            Crystal Palace
# 9                    Arsenal  [1.53, 5.75, 4.33]                   Arsenal
# 10               Southampton    [3.5, 2.15, 3.2]          Newcastle United
# 11                 Liverpool      [34, 1.09, 10]              Cardiff City
# 12                    Fulham   [2.45, 2.65, 3.6]               Bournemouth
# 13  Brighton and Hove Albion     [3.1, 2.4, 3.1]  Brighton and Hove Albion
# 14                   Watford    [4.8, 1.75, 3.4]         Huddersfield Town
# 15            Leicester City      [1.83, 4, 3.7]            Leicester City
# 16            Crystal Palace   [5.2, 1.67, 3.75]                   Arsenal
# 17                   Burnley     [1.83, 4, 3.75]                   Burnley
#
#     HomeOdds  AwayOdds  DrawOdds
# 0       1.70      5.00      3.80
# 1       2.40      2.80      3.30
# 2       2.15      3.60      3.10
# 3       2.00      3.60      3.50
# 4       1.07     34.00     13.00
# 5       1.73      5.00      3.50
# 6       4.00      1.80      3.50
# 7      12.00      1.30      5.00
# 8       1.83      4.33      3.50
# 9       1.53      5.75      4.33
# 10      2.15      3.50      3.20
# 11      1.09     34.00     10.00
# 12      2.65      2.45      3.60
# 13      3.10      2.40      3.10
# 14      1.75      4.80      3.40
# 15      1.83      4.00      3.70
# 16      1.67      5.20      3.75
# 17      1.83      4.00      3.75

# %%
def swap (row):
    if row[0]!= row[2]:
        return[row[0], row[1],row[2],row['AwayOdds'], row['DrawOdds'], row['HomeOdds']]
    else:
        return[row[0], row[1],row[2],row['HomeOdds'], row['DrawOdds'], row['AwayOdds']]

# %%
dict1=[{0:'Chelsea', 1: '[1.7, 5, 3.8]', 2:'Chelsea', 'AwayOdds' : 5.00, 'HomeOdds' : 1.70, 'DrawOdds':3.8},
      {0:'Cardiff City', 1: '[2.4, 2.8, 3.3]', 2:'Cardiff City', 'AwayOdds' : 1.7, 'HomeOdds' : 5.00, 'DrawOdds':3.8},
      {0:'Newcastle United', 1: '[2.4, 2.8, 3.3]', 2:'Brighton and Hove Albion', 'AwayOdds' : 2.15, 'HomeOdds' : 3.6, 'DrawOdds':3.8}
      ]

# %%
d = pd.DataFrame(dict1)

# %%
d[[0,1,2,'HomeOdds', 'DrawOdds', 'AwayOdds']]
# Out:
#                   0                1                         2  HomeOdds  \
# 0           Chelsea    [1.7, 5, 3.8]                   Chelsea       1.7
# 1      Cardiff City  [2.4, 2.8, 3.3]              Cardiff City       5.0
# 2  Newcastle United  [2.4, 2.8, 3.3]  Brighton and Hove Albion       3.6
#
#    DrawOdds  AwayOdds
# 0       3.8      5.00
# 1       3.8      1.70
# 2       3.8      2.15

# %%
d1=d[[0,1,2,'HomeOdds', 'DrawOdds', 'AwayOdds']].apply(swap,1)

# %%
d1[[0,1,2,'HomeOdds', 'DrawOdds', 'AwayOdds']]
# Out:
#                   0                1                         2 HomeOdds  \
# 0           Chelsea    [1.7, 5, 3.8]                   Chelsea      1.7
# 1      Cardiff City  [2.4, 2.8, 3.3]              Cardiff City        5
# 2  Newcastle United  [2.4, 2.8, 3.3]  Brighton and Hove Albion        a
#
#   DrawOdds AwayOdds
# 0      3.8        5
# 1      3.8      1.7
# 2        b        c

# %%
fix_pred=FixturesOdds()
fix_pred.fix_load('vwCSV_3','vwCSV_3.csv', False) # no reresh
fix_pred.do_calcs()

# %%
fix_pred.filter_by_col('fixDate', '2018-11-03')#.filter_by_col('leagueid',1)

# %%
fix_pred.df
# Out:
# Empty DataFrame
# Columns: [FixtureID, season, leagueid, fixDate, HomeTeamID, FTHG, AwayTeamID, FTAG, HomeELO_prev, AwayELO_prev, HomeTeamResult, AwayTeamResult, HomeTeam, AwayTeam, FTHG_3, FTAG_3, FTHG_5, FTAG_5, HomeOdds, DrawOdds, AwayOdds, FixtureDateAsDate, Target, HTRecord, ATRecord, ExpectedResult, FTG_3, FTG_5]
# Index: []
#
# [0 rows x 28 columns]
