# %%
# !pip3 install pandas
# Out:
# ...
#     100% |████████████████████████████████| 14.4MB 2.0MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 512kB 16.5MB/s ta 0:00:01
# ...

# %%
# !pip3 install pypyodbc
# Out:
# ...
#   Running setup.py bdist_wheel for pypyodbc ... done
#   Stored in directory: /Users/richard/Library/Caches/pip/wheels/e4/92/18/b21aa15a7e8915859a6fc10206cdd7f5d9ac098a523b9738c6
# Successfully built pypyodbc
# ...

# %%
import numpy as np
import pandas as pd
 
import pandas.io.sql as psql
import pypyodbc

# %%
print

# %%
conn = pypyodbc.connect('DSN=dockersql;DATABASE=fixtures_v2;UID=sa;PWD=Passw0rd')

# %%
waitstats = psql.read_sql('SELECT top 10 * from vwCSV_3', conn)
waitstats.head(10)
# Out:
#    fixtureid  season  leagueid    fixdate  hometeamid  fthg  awayteamid  ftag  \
# 0          5    2016         3 2017-03-04           4     1          25     1
# 1          1    2013         4 2014-05-03          49     3          25     2
# 2          6    2017         3 2017-09-16          26     0          25     1
# 3          7    2017         3 2017-09-02          27     1          25     0
# 4          2    2014         4 2014-09-13          49     1          25     0
# 5          3    2015         4 2015-10-20          49     3          25     4
# 6          8    2016         3 2017-04-22          28     3          25     0
# 7          4    2015         4 2016-02-20          50     1          25     2
# 8          9    2017         3 2018-01-27          28     0          25     4
# 9         13    2013         4 2013-11-30          29     3          25     0
#
#    ht_elo_prev  at_elo_prev    ...    awayteamresult            hometeam  \
# ...

# %%
nextfix = psql.read_sql('EXEC GetUpcomingFixtures 1', conn)
nextfix.head(10)
# Out:
#   fixdate           hometeam                 awayteam
# 0  01-Dec     Crystal Palace                  Burnley
# 1  01-Dec  Huddersfield Town   Brighton & Hove Albion
# 2  01-Dec     Leicester City                  Watford
# 3  01-Dec    Manchester City          AFC Bournemouth
# 4  01-Dec   Newcastle United          West Ham United
# 5  01-Dec        Southampton        Manchester United
# 6  02-Dec            Arsenal        Tottenham Hotspur
# 7  02-Dec            Chelsea                   Fulham
# 8  02-Dec          Liverpool                  Everton
# 9  30-Nov       Cardiff City  Wolverhampton Wanderers

# %%
pypyodbc
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1403             else:
# -> 1404                 cur.execute(*args)
#    1405             return cur
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pypyodbc.py in execute(self, query_string, params, many_mode, call_mode)
#    1616                 #print param_valparam_buffer, param_buffer.value
# -> 1617                 check_success(self, ret)
#    1618
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pypyodbc.py in check_success(ODBC_obj, ret)
#    1006         if isinstance(ODBC_obj, Cursor):
# -> 1007             ctrl_err(SQL_HANDLE_STMT, ODBC_obj.stmt_h, ret, ODBC_obj.ansi)
# ...
