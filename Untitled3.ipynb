# %%
import urllib.request
import datetime


import json
from dateutil import parser

# %%
url='http://api.football-data.org/v2/competitions/'

# %%
req = urllib.request.Request(url)
r = urllib.request.urlopen(req).read()

# %%
#parse json into an array of matches
competitions=json.loads(r.decode('utf-8'))

# %%
competitions['competitions']
# Out:
# [{'area': {'id': 2001, 'name': 'Africa'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 6,
#    'endDate': '2017-11-14',
#    'id': 7,
#    'startDate': '2015-10-07',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2006,
#   'lastUpdated': '2018-06-04T23:54:04Z',
#   'name': 'WC Qualification',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2011, 'name': 'Argentina'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-03-15',
#    'id': 27,
#    'startDate': '2018-03-15',
#    'winner': {'crestUrl': None,
#     'id': 2069,
#     'name': 'CA River Plate',
#     'shortName': 'River Plate',
#     'tla': 'RIV'}},
#   'emblemUrl': None,
#   'id': 2025,
#   'lastUpdated': '2018-06-04T23:54:32Z',
#   'name': 'Supercopa Argentina',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2011, 'name': 'Argentina'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 10,
#    'endDate': '2019-04-20',
#    'id': 295,
#    'startDate': '2018-08-25',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2023,
#   'lastUpdated': '2018-11-12T00:45:11Z',
#   'name': 'Primera B Nacional',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2011, 'name': 'Argentina'},
#   'code': 'ASL',
#   'currentSeason': {'currentMatchday': 12,
#    'endDate': '2019-04-07',
#    'id': 282,
#    'startDate': '2018-08-11',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2024,
#   'lastUpdated': '2018-11-12T00:25:09Z',
#   'name': 'Superliga Argentina',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2015, 'name': 'Australia'},
#   'code': 'AAL',
#   'currentSeason': {'currentMatchday': 4,
#    'endDate': '2019-04-28',
#    'id': 283,
#    'startDate': '2018-10-19',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2008,
#   'lastUpdated': '2018-11-11T12:25:22Z',
#   'name': 'A League',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2015, 'name': 'Australia'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-29',
#    'id': 28,
#    'startDate': '2018-02-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2026,
#   'lastUpdated': '2018-10-30T12:09:45Z',
#   'name': 'FFA Cup',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2016, 'name': 'Austria'},
#   'code': 'ABL',
#   'currentSeason': {'currentMatchday': 14,
#    'endDate': '2019-03-17',
#    'id': 208,
#    'startDate': '2018-07-27',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2012,
#   'lastUpdated': '2018-11-11T19:40:47Z',
#   'name': 'Bundesliga',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2016, 'name': 'Austria'},
#   'code': 'APL',
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-06-03',
#    'id': 24,
#    'startDate': '2018-05-31',
#    'winner': {'crestUrl': None,
#     'id': 2022,
#     'name': 'SKN Sankt Pölten',
#     'shortName': 'St. Pölten',
#     'tla': 'STP'}},
#   'emblemUrl': None,
#   'id': 2022,
#   'lastUpdated': '2018-08-23T15:47:33Z',
#   'name': 'Playoffs 1/2',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2016, 'name': 'Austria'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-09-25',
#    'id': 162,
#    'startDate': '2018-07-20',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2027,
#   'lastUpdated': '2018-11-01T15:26:04Z',
#   'name': 'ÖFB Cup',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2016, 'name': 'Austria'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 14,
#    'endDate': '2019-06-01',
#    'id': 161,
#    'startDate': '2018-07-27',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2020,
#   'lastUpdated': '2018-11-11T16:16:17Z',
#   'name': 'Erste Liga',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2023, 'name': 'Belgium'},
#   'code': 'BJL',
#   'currentSeason': {'currentMatchday': 15,
#    'endDate': '2019-03-17',
#    'id': 163,
#    'startDate': '2018-07-27',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2009,
#   'lastUpdated': '2018-11-11T22:40:22Z',
#   'name': 'Jupiler Pro League',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2023, 'name': 'Belgium'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-03-17',
#    'id': 30,
#    'startDate': '2017-07-28',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2028,
#   'lastUpdated': '2018-06-04T23:58:29Z',
#   'name': 'Coupe de Belgique',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2023, 'name': 'Belgium'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-07-22',
#    'id': 165,
#    'startDate': '2018-07-22',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2010,
#   'lastUpdated': '2018-06-04T23:58:10Z',
#   'name': 'Supercoupe de Belgique',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2023, 'name': 'Belgium'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-05-23',
#    'id': 34,
#    'startDate': '2018-03-31',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2032,
#   'lastUpdated': '2018-06-02T13:08:02Z',
#   'name': 'Playoffs II',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2023, 'name': 'Belgium'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 14,
#    'endDate': '2019-03-01',
#    'id': 164,
#    'startDate': '2018-08-03',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2033,
#   'lastUpdated': '2018-11-10T11:35:02Z',
#   'name': 'Division 1B',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2028, 'name': 'Bolivia'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 19,
#    'endDate': '2018-11-28',
#    'id': 36,
#    'startDate': '2018-01-27',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2034,
#   'lastUpdated': '2018-11-12T00:33:07Z',
#   'name': 'LFPB',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2030, 'name': 'Bosnia and Herzegovina'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 17,
#    'endDate': '2019-02-09',
#    'id': 167,
#    'startDate': '2018-07-21',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2035,
#   'lastUpdated': '2018-11-11T18:22:27Z',
#   'name': 'Premier Liga',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2032, 'name': 'Brazil'},
#   'code': 'BSA',
#   'currentSeason': {'currentMatchday': 33,
#    'endDate': '2018-12-02',
#    'id': 15,
#    'startDate': '2018-04-14',
#    'winner': {'crestUrl': None,
#     'id': 1776,
#     'name': 'São Paulo FC',
#     'shortName': 'São Paulo',
#     'tla': 'SAO'}},
#   'emblemUrl': None,
#   'id': 2013,
#   'lastUpdated': '2018-11-12T00:40:09Z',
#   'name': 'Série A',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_ONE'},
#  {'area': {'id': 2032, 'name': 'Brazil'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 6,
#    'endDate': '2018-08-04',
#    'id': 40,
#    'startDate': '2018-04-21',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2038,
#   'lastUpdated': '2018-06-04T23:59:34Z',
#   'name': 'Série D',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2032, 'name': 'Brazil'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 18,
#    'endDate': '2018-08-28',
#    'id': 38,
#    'startDate': '2018-04-14',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2036,
#   'lastUpdated': '2018-09-24T02:30:06Z',
#   'name': 'Série C',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2032, 'name': 'Brazil'},
#   'code': 'BSB',
#   'currentSeason': {'currentMatchday': 36,
#    'endDate': '2018-11-24',
#    'id': 31,
#    'startDate': '2018-04-14',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2029,
#   'lastUpdated': '2018-11-11T21:40:12Z',
#   'name': 'Série B',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2032, 'name': 'Brazil'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-17',
#    'id': 39,
#    'startDate': '2018-01-30',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2037,
#   'lastUpdated': '2018-10-19T23:40:00Z',
#   'name': 'Copa do Brasil',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2035, 'name': 'Bulgaria'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-05-09',
#    'id': 41,
#    'startDate': '2017-09-19',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2039,
#   'lastUpdated': '2018-06-05T00:00:10Z',
#   'name': 'Kupa na Bulgarija',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2035, 'name': 'Bulgaria'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 15,
#    'endDate': '2019-03-16',
#    'id': 168,
#    'startDate': '2018-07-20',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2040,
#   'lastUpdated': '2018-11-11T18:25:27Z',
#   'name': 'A PFG',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2040, 'name': 'Canada'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-16',
#    'id': 43,
#    'startDate': '2018-06-07',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2041,
#   'lastUpdated': '2018-06-05T00:01:12Z',
#   'name': 'Canadian Championship',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2045, 'name': 'Chile'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-01-26',
#    'id': 45,
#    'startDate': '2018-01-26',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2043,
#   'lastUpdated': '2018-06-05T00:01:51Z',
#   'name': 'Supercopa de Chile',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2045, 'name': 'Chile'},
#   'code': 'CPD',
#   'currentSeason': {'currentMatchday': 28,
#    'endDate': '2018-12-01',
#    'id': 51,
#    'startDate': '2018-02-03',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2048,
#   'lastUpdated': '2018-11-11T01:25:20Z',
#   'name': 'Primera División',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2045, 'name': 'Chile'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2017-12-21',
#    'id': 44,
#    'startDate': '2017-11-25',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2042,
#   'lastUpdated': '2018-06-05T00:01:23Z',
#   'name': 'Playoffs 1/2',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2046, 'name': 'China PR'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 30,
#    'endDate': '2018-11-12',
#    'id': 46,
#    'startDate': '2018-03-02',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2044,
#   'lastUpdated': '2018-11-11T17:31:36Z',
#   'name': 'Chinese Super League',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2049, 'name': 'Colombia'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 19,
#    'endDate': '2018-11-11',
#    'id': 47,
#    'startDate': '2018-02-03',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2045,
#   'lastUpdated': '2018-11-12T00:45:09Z',
#   'name': 'Liga Postobón',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2049, 'name': 'Colombia'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-02-08',
#    'id': 48,
#    'startDate': '2018-02-01',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2046,
#   'lastUpdated': '2018-06-05T00:02:32Z',
#   'name': 'Superliga de Colombia',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2058, 'name': 'Croatia'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 14,
#    'endDate': '2019-05-25',
#    'id': 170,
#    'startDate': '2018-07-27',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2047,
#   'lastUpdated': '2018-11-11T20:09:07Z',
#   'name': 'Prva Liga',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2062, 'name': 'Czech Republic'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 15,
#    'endDate': '2019-04-27',
#    'id': 171,
#    'startDate': '2018-07-20',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2049,
#   'lastUpdated': '2018-11-11T19:08:20Z',
#   'name': 'Synot Liga',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2065, 'name': 'Denmark'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-15',
#    'id': 173,
#    'startDate': '2018-08-07',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2051,
#   'lastUpdated': '2018-11-08T04:40:01Z',
#   'name': 'DBU Pokalen',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2065, 'name': 'Denmark'},
#   'code': None,
#   'currentSeason': None,
#   'emblemUrl': None,
#   'id': 2141,
#   'lastUpdated': '2018-07-13T13:34:22Z',
#   'name': 'Play Offs 1/2',
#   'numberOfAvailableSeasons': 0,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2065, 'name': 'Denmark'},
#   'code': 'DSU',
#   'currentSeason': {'currentMatchday': 16,
#    'endDate': '2019-03-17',
#    'id': 172,
#    'startDate': '2018-07-13',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2050,
#   'lastUpdated': '2018-11-11T22:39:55Z',
#   'name': 'Superliga',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2069, 'name': 'Ecuador'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 18,
#    'endDate': '2018-12-09',
#    'id': 55,
#    'startDate': '2018-02-17',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2052,
#   'lastUpdated': '2018-11-12T00:45:09Z',
#   'name': 'Copa Pilsener Serie A',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2072, 'name': 'England'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-05',
#    'id': 60,
#    'startDate': '2018-08-05',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2056,
#   'lastUpdated': '2018-06-05T00:05:10Z',
#   'name': 'FA Community Shield',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2072, 'name': 'England'},
#   'code': 'EL1',
#   'currentSeason': {'currentMatchday': 18,
#    'endDate': '2019-05-04',
#    'id': 152,
#    'startDate': '2018-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2030,
#   'lastUpdated': '2018-11-06T23:25:20Z',
#   'name': 'League One',
#   'numberOfAvailableSeasons': 10,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2072, 'name': 'England'},
#   'code': 'PL',
#   'currentSeason': {'currentMatchday': 12,
#    'endDate': '2019-05-12',
#    'id': 151,
#    'startDate': '2018-08-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2021,
#   'lastUpdated': '2018-11-11T21:40:12Z',
#   'name': 'Premier League',
#   'numberOfAvailableSeasons': 26,
#   'plan': 'TIER_ONE'},
#  {'area': {'id': 2072, 'name': 'England'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 20,
#    'endDate': '2019-04-27',
#    'id': 174,
#    'startDate': '2018-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2053,
#   'lastUpdated': '2018-11-03T19:21:23Z',
#   'name': 'National League',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2072, 'name': 'England'},
#   'code': 'FLC',
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-29',
#    'id': 176,
#    'startDate': '2018-08-14',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2139,
#   'lastUpdated': '2018-11-01T23:24:43Z',
#   'name': 'Football League Cup',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2072, 'name': 'England'},
#   'code': 'EL2',
#   'currentSeason': {'currentMatchday': 18,
#    'endDate': '2019-05-04',
#    'id': 153,
#    'startDate': '2018-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2054,
#   'lastUpdated': '2018-11-06T23:25:20Z',
#   'name': 'League Two',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2072, 'name': 'England'},
#   'code': 'FAC',
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-27',
#    'id': 207,
#    'startDate': '2018-08-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2055,
#   'lastUpdated': '2018-11-11T18:15:26Z',
#   'name': 'FA Cup',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2072, 'name': 'England'},
#   'code': 'ELC',
#   'currentSeason': {'currentMatchday': 17,
#    'endDate': '2019-05-05',
#    'id': 154,
#    'startDate': '2018-08-03',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2016,
#   'lastUpdated': '2018-11-11T21:40:12Z',
#   'name': 'Championship',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_ONE'},
#  {'area': {'id': 2075, 'name': 'Estonia'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 36,
#    'endDate': '2018-11-10',
#    'id': 61,
#    'startDate': '2018-03-03',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2057,
#   'lastUpdated': '2018-11-10T21:12:18Z',
#   'name': 'Meistriliiga',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2077, 'name': 'Europe'},
#   'code': 'CL',
#   'currentSeason': {'currentMatchday': 5,
#    'endDate': '2019-06-01',
#    'id': 175,
#    'startDate': '2018-06-26',
#    'winner': None},
#   'emblemUrl': 'https://upload.wikimedia.org/wikipedia/en/b/bf/UEFA_Champions_League_logo_2.svg',
#   'id': 2001,
#   'lastUpdated': '2018-11-08T21:50:01Z',
#   'name': 'UEFA Champions League',
#   'numberOfAvailableSeasons': 19,
#   'plan': 'TIER_ONE'},
#  {'area': {'id': 2077, 'name': 'Europe'},
#   'code': 'EC',
#   'currentSeason': {'currentMatchday': 3,
#    'endDate': '2016-07-10',
#    'id': 20,
#    'startDate': '2016-06-10',
#    'winner': {'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/5/5c/Flag_of_Portugal.svg',
#     'id': 765,
#     'name': 'Portugal',
#     'shortName': 'Portugal',
#     'tla': 'POR'}},
#   'emblemUrl': None,
#   'id': 2018,
#   'lastUpdated': '2018-08-23T12:16:01Z',
#   'name': 'European Championship',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_ONE'},
#  {'area': {'id': 2077, 'name': 'Europe'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 3,
#    'endDate': '2017-08-06',
#    'id': 62,
#    'startDate': '2017-07-16',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2058,
#   'lastUpdated': '2018-06-05T00:06:08Z',
#   'name': "UEFA Women's EURO",
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2077, 'name': 'Europe'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 10,
#    'endDate': '2017-11-14',
#    'id': 8,
#    'startDate': '2016-09-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2007,
#   'lastUpdated': '2018-06-05T00:06:41Z',
#   'name': 'WC Qualification',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2077, 'name': 'Europe'},
#   'code': 'EL',
#   'currentSeason': {'currentMatchday': 5,
#    'endDate': '2019-05-29',
#    'id': 293,
#    'startDate': '2018-06-26',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2146,
#   'lastUpdated': '2018-11-09T17:55:01Z',
#   'name': 'UEFA Europa League',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2080, 'name': 'Finland'},
#   'code': 'VEI',
#   'currentSeason': {'currentMatchday': 33,
#    'endDate': '2018-10-27',
#    'id': 33,
#    'startDate': '2018-04-07',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2031,
#   'lastUpdated': '2018-11-03T17:36:56Z',
#   'name': 'Veikkausliiga',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2080, 'name': 'Finland'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-05-12',
#    'id': 63,
#    'startDate': '2018-01-19',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2059,
#   'lastUpdated': '2018-06-05T00:07:27Z',
#   'name': 'Suomen Cup',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2081, 'name': 'France'},
#   'code': 'FL2',
#   'currentSeason': {'currentMatchday': 14,
#    'endDate': '2019-05-17',
#    'id': 210,
#    'startDate': '2018-07-27',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2142,
#   'lastUpdated': '2018-11-10T18:30:47Z',
#   'name': 'Ligue 2',
#   'numberOfAvailableSeasons': 21,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2081, 'name': 'France'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-05-27',
#    'id': 211,
#    'startDate': '2018-05-23',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2143,
#   'lastUpdated': '2018-07-12T14:32:17Z',
#   'name': 'Playoffs 1/2',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2081, 'name': 'France'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-05-08',
#    'id': 147,
#    'startDate': '2017-11-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2138,
#   'lastUpdated': '2018-06-05T00:08:30Z',
#   'name': 'Coupe de France',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2081, 'name': 'France'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-28',
#    'id': 284,
#    'startDate': '2018-08-14',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2135,
#   'lastUpdated': '2018-11-01T10:15:05Z',
#   'name': 'Coupe de la Ligue',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2081, 'name': 'France'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-05-27',
#    'id': 212,
#    'startDate': '2018-05-22',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2144,
#   'lastUpdated': '2018-09-25T15:07:37Z',
#   'name': 'Playoffs 2/3',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2081, 'name': 'France'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-04',
#    'id': 206,
#    'startDate': '2018-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2136,
#   'lastUpdated': '2018-06-05T00:08:21Z',
#   'name': 'Trophée des Champions',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2081, 'name': 'France'},
#   'code': 'FL1',
#   'currentSeason': {'currentMatchday': 13,
#    'endDate': '2019-05-25',
#    'id': 177,
#    'startDate': '2018-08-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2015,
#   'lastUpdated': '2018-11-11T23:39:07Z',
#   'name': 'Ligue 1',
#   'numberOfAvailableSeasons': 8,
#   'plan': 'TIER_ONE'},
#  {'area': {'id': 2088, 'name': 'Germany'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-12',
#    'id': 158,
#    'startDate': '2018-08-12',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2134,
#   'lastUpdated': '2018-06-05T00:10:19Z',
#   'name': 'DFL Super Cup',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2088, 'name': 'Germany'},
#   'code': 'BL2',
#   'currentSeason': {'currentMatchday': 13,
#    'endDate': '2019-05-19',
#    'id': 157,
#    'startDate': '2018-08-03',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2004,
#   'lastUpdated': '2018-11-11T16:10:59Z',
#   'name': '2. Bundesliga',
#   'numberOfAvailableSeasons': 23,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2088, 'name': 'Germany'},
#   'code': 'REG',
#   'currentSeason': {'currentMatchday': 18,
#    'endDate': '2019-05-18',
#    'id': 178,
#    'startDate': '2018-07-12',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2129,
#   'lastUpdated': '2018-11-11T22:20:12Z',
#   'name': 'Regionalliga',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2088, 'name': 'Germany'},
#   'code': 'BL3',
#   'currentSeason': {'currentMatchday': 15,
#    'endDate': '2019-05-18',
#    'id': 150,
#    'startDate': '2018-07-27',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2140,
#   'lastUpdated': '2018-11-11T16:45:51Z',
#   'name': '3. Liga',
#   'numberOfAvailableSeasons': 6,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2088, 'name': 'Germany'},
#   'code': 'BL1',
#   'currentSeason': {'currentMatchday': 11,
#    'endDate': '2019-05-18',
#    'id': 155,
#    'startDate': '2018-08-24',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2002,
#   'lastUpdated': '2018-11-11T21:40:12Z',
#   'name': 'Bundesliga',
#   'numberOfAvailableSeasons': 23,
#   'plan': 'TIER_ONE'},
#  {'area': {'id': 2088, 'name': 'Germany'},
#   'code': 'DFB',
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-20',
#    'id': 12,
#    'startDate': '2018-08-17',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2011,
#   'lastUpdated': '2018-10-31T23:25:14Z',
#   'name': 'DFB-Pokal',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2088, 'name': 'Germany'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 22,
#    'endDate': '2018-06-03',
#    'id': 142,
#    'startDate': '2017-09-02',
#    'winner': {'crestUrl': None,
#     'id': 7522,
#     'name': 'VfL Wolfsburg',
#     'shortName': None,
#     'tla': None}},
#   'emblemUrl': None,
#   'id': 2133,
#   'lastUpdated': '2018-06-05T00:09:39Z',
#   'name': 'Frauen Bundesliga',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2093, 'name': 'Greece'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 3,
#    'endDate': '2018-05-12',
#    'id': 140,
#    'startDate': '2017-08-20',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2131,
#   'lastUpdated': '2018-06-05T00:10:49Z',
#   'name': 'Greek Cup',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2093, 'name': 'Greece'},
#   'code': 'GSL',
#   'currentSeason': {'currentMatchday': 10,
#    'endDate': '2019-05-05',
#    'id': 299,
#    'startDate': '2018-08-25',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2132,
#   'lastUpdated': '2018-11-11T21:40:12Z',
#   'name': 'Super League',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2106, 'name': 'Hungary'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2019-05-01',
#    'id': 297,
#    'startDate': '2019-09-22',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2130,
#   'lastUpdated': '2018-10-31T21:57:08Z',
#   'name': 'Magyar Kupa',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2106, 'name': 'Hungary'},
#   'code': 'HNB',
#   'currentSeason': {'currentMatchday': 14,
#    'endDate': '2019-05-19',
#    'id': 179,
#    'startDate': '2018-07-21',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2128,
#   'lastUpdated': '2018-11-11T18:37:58Z',
#   'name': 'NB I',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2107, 'name': 'Iceland'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 22,
#    'endDate': '2018-09-29',
#    'id': 136,
#    'startDate': '2018-04-27',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2127,
#   'lastUpdated': '2018-09-30T07:05:12Z',
#   'name': 'Úrvalsdeild',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2108, 'name': 'India'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-03-08',
#    'id': 135,
#    'startDate': '2017-11-25',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2126,
#   'lastUpdated': '2018-06-05T00:13:45Z',
#   'name': 'I-League',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2113, 'name': 'Israel'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 10,
#    'endDate': '2019-03-09',
#    'id': 205,
#    'startDate': '2018-08-25',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2125,
#   'lastUpdated': '2018-11-11T22:13:17Z',
#   'name': "Ligat ha'Al",
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2114, 'name': 'Italy'},
#   'code': 'SB',
#   'currentSeason': {'currentMatchday': 12,
#    'endDate': '2019-05-11',
#    'id': 294,
#    'startDate': '2018-08-24',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2121,
#   'lastUpdated': '2018-11-11T23:39:55Z',
#   'name': 'Serie B',
#   'numberOfAvailableSeasons': 14,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2114, 'name': 'Italy'},
#   'code': 'CIT',
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2019-01-13',
#    'id': 285,
#    'startDate': '2018-07-28',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2122,
#   'lastUpdated': '2018-08-23T15:52:02Z',
#   'name': 'Coppa Italia',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2114, 'name': 'Italy'},
#   'code': 'SA',
#   'currentSeason': {'currentMatchday': 12,
#    'endDate': '2019-05-26',
#    'id': 290,
#    'startDate': '2018-08-18',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2019,
#   'lastUpdated': '2018-11-11T23:09:56Z',
#   'name': 'Serie A',
#   'numberOfAvailableSeasons': 14,
#   'plan': 'TIER_ONE'},
#  {'area': {'id': 2114, 'name': 'Italy'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 38,
#    'endDate': '2018-06-16',
#    'id': 132,
#    'startDate': '2017-08-26',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2123,
#   'lastUpdated': '2018-11-11T22:40:22Z',
#   'name': 'Serie C',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2114, 'name': 'Italy'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2019-01-12',
#    'id': 159,
#    'startDate': '2019-01-12',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2124,
#   'lastUpdated': '2018-06-05T00:14:07Z',
#   'name': 'Supercoppa',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2116, 'name': 'Japan'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 41,
#    'endDate': '2018-11-16',
#    'id': 126,
#    'startDate': '2018-02-25',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2117,
#   'lastUpdated': '2018-11-11T13:27:15Z',
#   'name': 'J. League Division 2',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2116, 'name': 'Japan'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 6,
#    'endDate': '2018-09-09',
#    'id': 127,
#    'startDate': '2018-03-07',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2118,
#   'lastUpdated': '2018-10-27T23:29:20Z',
#   'name': 'J.League Cup',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2116, 'name': 'Japan'},
#   'code': 'JJL',
#   'currentSeason': {'currentMatchday': 32,
#    'endDate': '2018-12-01',
#    'id': 128,
#    'startDate': '2018-02-23',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2119,
#   'lastUpdated': '2018-11-10T09:39:46Z',
#   'name': 'J. League',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2116, 'name': 'Japan'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-02-10',
#    'id': 129,
#    'startDate': '2018-02-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2120,
#   'lastUpdated': '2018-06-05T00:15:43Z',
#   'name': 'Super Cup',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2129, 'name': 'Latvia'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 28,
#    'endDate': '2018-11-10',
#    'id': 125,
#    'startDate': '2018-03-31',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2116,
#   'lastUpdated': '2018-11-11T18:40:15Z',
#   'name': 'Virslīga',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2135, 'name': 'Lithuania'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 2,
#    'endDate': '2018-10-30',
#    'id': 124,
#    'startDate': '2018-02-24',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2115,
#   'lastUpdated': '2018-11-11T13:57:07Z',
#   'name': 'A Lyga',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2143, 'name': 'Malta'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 10,
#    'endDate': '2019-04-25',
#    'id': 160,
#    'startDate': '2018-08-17',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2114,
#   'lastUpdated': '2018-11-11T19:55:28Z',
#   'name': 'Premier League',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2149, 'name': 'Mexico'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-07-15',
#    'id': 121,
#    'startDate': '2018-07-15',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2112,
#   'lastUpdated': '2018-06-05T00:17:16Z',
#   'name': 'SuperCopa MX',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2149, 'name': 'Mexico'},
#   'code': 'LMX',
#   'currentSeason': {'currentMatchday': 16,
#    'endDate': '2018-11-25',
#    'id': 186,
#    'startDate': '2018-07-21',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2113,
#   'lastUpdated': '2018-11-12T00:45:11Z',
#   'name': 'Liga MX',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2149, 'name': 'Mexico'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 6,
#    'endDate': '2018-09-06',
#    'id': 187,
#    'startDate': '2018-07-25',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2111,
#   'lastUpdated': '2018-11-02T22:15:02Z',
#   'name': 'Copa MX',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2163, 'name': 'Netherlands'},
#   'code': 'DJL',
#   'currentSeason': {'currentMatchday': 13,
#    'endDate': '2019-05-03',
#    'id': 180,
#    'startDate': '2018-08-17',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2005,
#   'lastUpdated': '2018-11-10T18:30:03Z',
#   'name': 'Jupiler League',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2163, 'name': 'Netherlands'},
#   'code': 'KNV',
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-25',
#    'id': 181,
#    'startDate': '2018-08-18',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2109,
#   'lastUpdated': '2018-11-02T11:15:02Z',
#   'name': 'KNVB Beker',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2163, 'name': 'Netherlands'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-04',
#    'id': 182,
#    'startDate': '2018-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2110,
#   'lastUpdated': '2018-06-05T00:18:23Z',
#   'name': 'Johan Cruijff Schaal',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2163, 'name': 'Netherlands'},
#   'code': 'DED',
#   'currentSeason': {'currentMatchday': 12,
#    'endDate': '2019-05-12',
#    'id': 156,
#    'startDate': '2018-08-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2003,
#   'lastUpdated': '2018-11-11T21:40:12Z',
#   'name': 'Eredivisie',
#   'numberOfAvailableSeasons': 9,
#   'plan': 'TIER_ONE'},
#  {'area': {'id': 2171, 'name': 'Northern Ireland'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-28',
#    'id': 203,
#    'startDate': '2018-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2108,
#   'lastUpdated': '2018-10-30T23:24:06Z',
#   'name': 'League Cup',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2171, 'name': 'Northern Ireland'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 15,
#    'endDate': '2019-03-23',
#    'id': 204,
#    'startDate': '2018-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2107,
#   'lastUpdated': '2018-11-10T18:24:18Z',
#   'name': 'Premiership',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2173, 'name': 'Norway'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2017-12-02',
#    'id': 112,
#    'startDate': '2017-11-29',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2104,
#   'lastUpdated': '2018-06-05T00:20:23Z',
#   'name': 'Playoffs 1/2',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2173, 'name': 'Norway'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 30,
#    'endDate': '2018-11-11',
#    'id': 113,
#    'startDate': '2018-04-02',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2105,
#   'lastUpdated': '2018-11-11T22:17:35Z',
#   'name': '1. divisjon',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2173, 'name': 'Norway'},
#   'code': 'TIP',
#   'currentSeason': {'currentMatchday': 29,
#    'endDate': '2018-11-25',
#    'id': 114,
#    'startDate': '2018-03-11',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2106,
#   'lastUpdated': '2018-11-11T20:40:47Z',
#   'name': 'Tippeligaen',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2175, 'name': 'Oceania'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 6,
#    'endDate': '2017-09-05',
#    'id': 111,
#    'startDate': '2015-08-31',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2103,
#   'lastUpdated': '2018-06-05T00:20:43Z',
#   'name': 'WC Qualification',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2181, 'name': 'Panama'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 18,
#    'endDate': '2018-05-20',
#    'id': 110,
#    'startDate': '2017-07-15',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2102,
#   'lastUpdated': '2018-06-05T00:21:02Z',
#   'name': 'Liga Panameña de Fútbol',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2184, 'name': 'Peru'},
#   'code': 'PPD',
#   'currentSeason': {'currentMatchday': 14,
#    'endDate': '2018-11-25',
#    'id': 109,
#    'startDate': '2018-02-03',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2101,
#   'lastUpdated': '2018-11-12T00:45:11Z',
#   'name': 'Primera División',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2186, 'name': 'Poland'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-07-14',
#    'id': 107,
#    'startDate': '2018-07-14',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2099,
#   'lastUpdated': '2018-06-05T00:21:44Z',
#   'name': 'Superpuchar Polski',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2186, 'name': 'Poland'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-09-25',
#    'id': 198,
#    'startDate': '2018-08-07',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2100,
#   'lastUpdated': '2018-11-07T21:09:07Z',
#   'name': 'Puchar Polski',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2187, 'name': 'Portugal'},
#   'code': 'PPL',
#   'currentSeason': {'currentMatchday': 10,
#    'endDate': '2019-05-19',
#    'id': 183,
#    'startDate': '2018-08-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2017,
#   'lastUpdated': '2018-11-11T23:39:35Z',
#   'name': 'Primeira Liga',
#   'numberOfAvailableSeasons': 8,
#   'plan': 'TIER_ONE'},
#  {'area': {'id': 2187, 'name': 'Portugal'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 9,
#    'endDate': '2019-05-19',
#    'id': 184,
#    'startDate': '2018-08-11',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2096,
#   'lastUpdated': '2018-11-11T19:55:28Z',
#   'name': 'Liga2 Cabovisão',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2187, 'name': 'Portugal'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-04',
#    'id': 104,
#    'startDate': '2018-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2097,
#   'lastUpdated': '2018-06-05T00:22:37Z',
#   'name': 'Supertaça Cândido de Oliveira',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2187, 'name': 'Portugal'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-05-20',
#    'id': 105,
#    'startDate': '2017-09-02',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2098,
#   'lastUpdated': '2018-06-05T00:22:53Z',
#   'name': 'Taça de Portugal',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2192, 'name': 'Republic of Ireland'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 36,
#    'endDate': '2018-10-26',
#    'id': 101,
#    'startDate': '2018-02-16',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2095,
#   'lastUpdated': '2018-10-27T15:10:10Z',
#   'name': 'Premier Division',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2194, 'name': 'Romania'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 38,
#    'endDate': '2018-06-13',
#    'id': 98,
#    'startDate': '2017-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2092,
#   'lastUpdated': '2018-06-05T00:23:34Z',
#   'name': 'Liga II',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2194, 'name': 'Romania'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-07-14',
#    'id': 202,
#    'startDate': '2018-07-14',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2093,
#   'lastUpdated': '2018-06-05T00:23:54Z',
#   'name': 'Supercupa României',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2194, 'name': 'Romania'},
#   'code': 'RL1',
#   'currentSeason': {'currentMatchday': 15,
#    'endDate': '2019-03-02',
#    'id': 185,
#    'startDate': '2018-07-20',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2094,
#   'lastUpdated': '2018-11-11T22:39:55Z',
#   'name': 'Liga I',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2195, 'name': 'Russia'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-07-27',
#    'id': 199,
#    'startDate': '2018-07-27',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2091,
#   'lastUpdated': '2018-06-05T00:24:42Z',
#   'name': 'Russian Super Cup',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2195, 'name': 'Russia'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-05-20',
#    'id': 96,
#    'startDate': '2018-05-17',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2090,
#   'lastUpdated': '2018-06-05T00:24:32Z',
#   'name': 'Playoffs 1/2',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2195, 'name': 'Russia'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 21,
#    'endDate': '2019-05-25',
#    'id': 200,
#    'startDate': '2018-07-17',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2088,
#   'lastUpdated': '2018-11-11T15:00:15Z',
#   'name': 'FNL',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2195, 'name': 'Russia'},
#   'code': 'RFPL',
#   'currentSeason': {'currentMatchday': 14,
#    'endDate': '2019-05-26',
#    'id': 201,
#    'startDate': '2018-07-28',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2137,
#   'lastUpdated': '2018-11-11T19:40:47Z',
#   'name': 'RFPL',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2195, 'name': 'Russia'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-22',
#    'id': 287,
#    'startDate': '2018-07-21',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2089,
#   'lastUpdated': '2018-11-01T19:54:23Z',
#   'name': 'Russian Cup',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2204, 'name': 'Scotland'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-05-13',
#    'id': 92,
#    'startDate': '2018-05-02',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2086,
#   'lastUpdated': '2018-06-05T00:25:54Z',
#   'name': 'Playoffs 2/3',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2204, 'name': 'Scotland'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-09-01',
#    'id': 288,
#    'startDate': '2018-08-11',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2087,
#   'lastUpdated': '2018-10-27T18:48:00Z',
#   'name': 'Scottish Cup',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2204, 'name': 'Scotland'},
#   'code': 'SPL',
#   'currentSeason': {'currentMatchday': 13,
#    'endDate': '2019-04-06',
#    'id': 196,
#    'startDate': '2018-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2084,
#   'lastUpdated': '2018-11-11T18:40:47Z',
#   'name': 'Premier League',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2204, 'name': 'Scotland'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 13,
#    'endDate': '2019-05-04',
#    'id': 197,
#    'startDate': '2018-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2085,
#   'lastUpdated': '2018-11-10T19:37:09Z',
#   'name': 'Championship',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2219, 'name': 'South Africa'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 10,
#    'endDate': '2019-08-11',
#    'id': 289,
#    'startDate': '2018-08-04',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2083,
#   'lastUpdated': '2018-11-11T21:40:12Z',
#   'name': 'ABSA Premiership',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2220, 'name': 'South America'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 18,
#    'endDate': '2017-10-11',
#    'id': 88,
#    'startDate': '2015-10-08',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2082,
#   'lastUpdated': '2018-06-05T00:27:01Z',
#   'name': 'WC Qualification',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2220, 'name': 'South America'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2019-06-06',
#    'id': 85,
#    'startDate': '2019-06-30',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2080,
#   'lastUpdated': '2018-06-05T00:26:43Z',
#   'name': 'Copa America',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2220, 'name': 'South America'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-10-03',
#    'id': 87,
#    'startDate': '2018-02-13',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2081,
#   'lastUpdated': '2018-11-09T03:41:28Z',
#   'name': 'Copa Sudamericana',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2224, 'name': 'Spain'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-14',
#    'id': 83,
#    'startDate': '2018-08-12',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2078,
#   'lastUpdated': '2018-06-05T00:27:12Z',
#   'name': 'Supercopa de España',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2224, 'name': 'Spain'},
#   'code': 'SD',
#   'currentSeason': {'currentMatchday': 13,
#    'endDate': '2019-06-09',
#    'id': 286,
#    'startDate': '2018-08-17',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2077,
#   'lastUpdated': '2018-11-11T22:39:55Z',
#   'name': 'Segunda División',
#   'numberOfAvailableSeasons': 7,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2224, 'name': 'Spain'},
#   'code': 'CDR',
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2019-03-30',
#    'id': 291,
#    'startDate': '2018-09-05',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2079,
#   'lastUpdated': '2018-11-02T11:15:02Z',
#   'name': 'Copa del Rey',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2224, 'name': 'Spain'},
#   'code': 'PD',
#   'currentSeason': {'currentMatchday': 12,
#    'endDate': '2019-05-26',
#    'id': 281,
#    'startDate': '2018-08-17',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2014,
#   'lastUpdated': '2018-11-11T23:24:55Z',
#   'name': 'Primera Division',
#   'numberOfAvailableSeasons': 26,
#   'plan': 'TIER_ONE'},
#  {'area': {'id': 2233, 'name': 'Sweden'},
#   'code': 'ALL',
#   'currentSeason': {'currentMatchday': 30,
#    'endDate': '2018-11-11',
#    'id': 77,
#    'startDate': '2018-04-01',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2073,
#   'lastUpdated': '2018-11-11T17:40:27Z',
#   'name': 'Allsvenskan',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2233, 'name': 'Sweden'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 30,
#    'endDate': '2018-11-10',
#    'id': 78,
#    'startDate': '2018-03-31',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2074,
#   'lastUpdated': '2018-11-11T12:35:12Z',
#   'name': 'Superettan',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2233, 'name': 'Sweden'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2017-11-11',
#    'id': 79,
#    'startDate': '2017-11-08',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2075,
#   'lastUpdated': '2018-06-05T00:28:43Z',
#   'name': 'Playoffs 2/3',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2233, 'name': 'Sweden'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2017-11-19',
#    'id': 80,
#    'startDate': '2017-11-15',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2076,
#   'lastUpdated': '2018-06-05T00:28:54Z',
#   'name': 'Playoffs 1/2',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2234, 'name': 'Switzerland'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-19',
#    'id': 194,
#    'startDate': '2018-08-18',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2071,
#   'lastUpdated': '2018-11-02T11:25:01Z',
#   'name': 'Schweizer Pokal',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2234, 'name': 'Switzerland'},
#   'code': 'SSL',
#   'currentSeason': {'currentMatchday': 14,
#    'endDate': '2019-05-25',
#    'id': 195,
#    'startDate': '2018-07-21',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2072,
#   'lastUpdated': '2018-11-11T21:40:12Z',
#   'name': 'Super League',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2247, 'name': 'Turkey'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2017-08-06',
#    'id': 73,
#    'startDate': '2017-08-06',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2069,
#   'lastUpdated': '2018-06-05T00:30:33Z',
#   'name': 'TFF Süper Kupa',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2247, 'name': 'Turkey'},
#   'code': 'TSL',
#   'currentSeason': {'currentMatchday': 12,
#    'endDate': '2019-05-26',
#    'id': 192,
#    'startDate': '2018-08-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2070,
#   'lastUpdated': '2018-11-11T21:10:24Z',
#   'name': 'Süper Lig',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2247, 'name': 'Turkey'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 12,
#    'endDate': '2019-05-18',
#    'id': 193,
#    'startDate': '2018-08-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2068,
#   'lastUpdated': '2018-11-11T19:02:18Z',
#   'name': '1. Lig',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2253, 'name': 'Ukraine'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-08-22',
#    'id': 190,
#    'startDate': '2018-07-17',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2065,
#   'lastUpdated': '2018-10-31T23:25:14Z',
#   'name': 'Kubok Ukrainy',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2253, 'name': 'Ukraine'},
#   'code': 'UPL',
#   'currentSeason': {'currentMatchday': 11,
#    'endDate': '2018-10-06',
#    'id': 189,
#    'startDate': '2018-07-22',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2064,
#   'lastUpdated': '2018-11-11T21:40:12Z',
#   'name': 'Premier Liha',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_THREE'},
#  {'area': {'id': 2253, 'name': 'Ukraine'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-05-27',
#    'id': 70,
#    'startDate': '2018-05-23',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2066,
#   'lastUpdated': '2018-06-02T14:03:07Z',
#   'name': 'Playoffs 1/2',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2253, 'name': 'Ukraine'},
#   'code': None,
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-07-21',
#    'id': 191,
#    'startDate': '2018-07-21',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2067,
#   'lastUpdated': '2018-06-05T00:30:59Z',
#   'name': 'Superkubok Ukrainy',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2256, 'name': 'United States'},
#   'code': 'MLS',
#   'currentSeason': {'currentMatchday': None,
#    'endDate': '2018-10-28',
#    'id': 292,
#    'startDate': '2018-03-03',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2145,
#   'lastUpdated': '2018-11-12T00:45:09Z',
#   'name': 'MLS',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_TWO'},
#  {'area': {'id': 2257, 'name': 'Uruguay'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 14,
#    'endDate': '2018-10-28',
#    'id': 67,
#    'startDate': '2018-02-03',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2063,
#   'lastUpdated': '2018-11-11T23:21:26Z',
#   'name': 'Primera División',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2262, 'name': 'Venezuela'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 17,
#    'endDate': '2018-11-04',
#    'id': 66,
#    'startDate': '2018-01-27',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2062,
#   'lastUpdated': '2018-11-09T03:50:01Z',
#   'name': 'Primera División',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2263, 'name': 'Vietnam'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 26,
#    'endDate': '2018-10-06',
#    'id': 65,
#    'startDate': '2018-03-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2061,
#   'lastUpdated': '2018-10-08T14:27:29Z',
#   'name': 'V-League',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2264, 'name': 'Wales'},
#   'code': None,
#   'currentSeason': {'currentMatchday': 14,
#    'endDate': '2019-01-12',
#    'id': 188,
#    'startDate': '2018-08-10',
#    'winner': None},
#   'emblemUrl': None,
#   'id': 2060,
#   'lastUpdated': '2018-11-11T19:55:28Z',
#   'name': 'Welsh Premier League',
#   'numberOfAvailableSeasons': 2,
#   'plan': 'TIER_FOUR'},
#  {'area': {'id': 2267, 'name': 'World'},
#   'code': 'WC',
#   'currentSeason': {'currentMatchday': 3,
#    'endDate': '2018-07-15',
#    'id': 1,
#    'startDate': '2018-06-14',
#    'winner': {'crestUrl': 'https://upload.wikimedia.org/wikipedia/en/c/c3/Flag_of_France.svg',
#     'id': 773,
#     'name': 'France',
#     'shortName': 'France',
#     'tla': 'FRA'}},
#   'emblemUrl': None,
#   'id': 2000,
#   'lastUpdated': '2018-08-23T12:16:17Z',
#   'name': 'FIFA World Cup',
#   'numberOfAvailableSeasons': 1,
#   'plan': 'TIER_ONE'}]
